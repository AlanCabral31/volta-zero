# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
r = requests.get(url)

data_json = r.json()
df = pd.DataFrame(data_json['items'])

df_rj = df[df['uf'] == 'RJ']
df_rj
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 45        56075        Município         Resende   3304201  RJ
# 135       42252        Município        Itatiaia   3302254  RJ
# 296       70657        Município         Niterói   3303302  RJ
# 298       63612        Município         Resende   3304201  RJ
# 631        9075        Município  Barra do Piraí   3300308  RJ
# ...         ...              ...             ...       ...  ..
# 4619      11202        Município  Rio de Janeiro   3304557  RJ
# 4728       5267        Município  Paraíba do Sul   3303708  RJ
# 4817      28822        Município         Resende   3304201  RJ
# 4827       5914        Município       Nilópolis   3303203  RJ
# 4990      11272        Município  Rio de Janeiro   3304557  RJ
#
#                    num_pvl                                             status  \
# 45    PVL02.003504/2022-85                                  Deferido (PVL-IF)
# 135   PVL02.000042/2020-82  Encaminhado à PGFN com manifestação técnica fa...
# 296   PVL02.001291/2024-19            Assinado pelo interessado (retificação)
# 298   PVL02.008921/2022-14                                 Arquivado a pedido
# 631                   None                                          Arquivado
# ...                    ...                                                ...
# 4619                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4728                  None                                       Regularizado
# 4817  PVL02.001389/2018-28                                           Deferido
# 4827                  None                                       Regularizado
# 4990                  None                                           Deferido
#
#               num_processo        data_protocolo  \
# 45                    None                  None
# 135   17944.101489/2020-31  2020-05-19T10:29:59Z
# 296   17944.000810/2025-75  2025-03-19T15:17:56Z
# 298   17944.100828/2023-12  2023-08-24T14:59:04Z
# 631   17944.000898/2008-24  2008-08-18T00:00:00Z
# ...                    ...                   ...
# 4619  17944.001383/2012-28  2013-07-19T00:00:00Z
# 4728  17944.000073/2014-58  2023-03-13T15:24:36Z
# 4817  17944.105556/2018-71  2018-07-10T17:20:13Z
# 4827  17944.000231/2012-16  2012-08-20T00:00:00Z
# 4990  17944.001398/2013-77  2013-11-25T00:00:00Z
#
#                                           tipo_operacao  \
# 45                          Operação contratual interna
# 135   Operação contratual interna (com garantia da U...
# 296   Operação contratual interna (com garantia da U...
# 298   Operação contratual interna (com garantia da U...
# 631                         Operação contratual interna
# ...                                                 ...
# 4619  Operação contratual externa (com garantia da U...
# 4728                        Operação contratual interna
# 4817                        Operação contratual interna
# 4827                        Operação contratual interna
# 4990                        Operação contratual interna
#
#                                              finalidade  \
# 45       Aquisição de máquinas, equipamentos e veículos
# 135                                      Infraestrutura
# 296                                            Novo PAC
# 298                                      Infraestrutura
# 631                                 Caminho da Escola 2
# ...                                                 ...
# 4619                                     Multissetorial
# 4728         Regularização de Dívida - Energia Elétrica
# 4817                                     Infraestrutura
# 4827         Regularização de Dívida - Energia Elétrica
# 4990  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
#
#                                tipo_credor  \
# 45         Instituição Financeira Nacional
# 135        Instituição Financeira Nacional
# 296        Instituição Financeira Nacional
# 298        Instituição Financeira Nacional
# 631        Instituição Financeira Nacional
# ...                                    ...
# 4619  Instituição Financeira Internacional
# 4728                   Empresa Não Estatal
# 4817       Instituição Financeira Nacional
# 4827                   Empresa Não Estatal
# 4990       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 45                                  Banco do Brasil S/A           Real
# 135                                 Banco do Brasil S/A           Real
# 296                             Caixa Econômica Federal           Real
# 298                                 Banco do Brasil S/A           Real
# 631                                 Banco do Brasil S/A           Real
# ...                                                 ...            ...
# 4619  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4728               Light - Serviços de Eletricidade S/A           Real
# 4817                                Banco do Brasil S/A           Real
# 4827               Light - Serviços de Eletricidade S/A           Real
# 4990                            Caixa Econômica Federal           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 45    2.160000e+06                 0                      1  28/07/2022
# 135   3.000000e+07                 1                      1  21/05/2020
# 296   9.534000e+07                 0                      0  31/03/2025
# 298   3.200000e+07                 0                      0  23/11/2023
# 631   4.594000e+05                 0                      0  30/10/2008
# ...            ...               ...                    ...         ...
# 4619  1.620000e+07                 1                      0  13/08/2013
# 4728  2.358312e+07                 0                      0  20/03/2023
# 4817  7.000000e+06                 0                      1  12/07/2018
# 4827  4.178062e+06                 0                      0  05/09/2012
# 4990  5.000000e+08                 1                      0  06/12/2013
#
# [65 rows x 18 columns]

# %%
# 2) Seu código aqui
top3_status = df_rj['status'].value_counts().head(3)
top3_status
# Out:
# status
# Deferido                                                 24
# Arquivado                                                11
# Encaminhado à PGFN com manifestação técnica favorável     8
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df_rj = df[df['uf'] == 'RJ'].copy()  
df_rj['ano_status'] = df_rj['data_status'].str.split('/').str[2] 
df_rj[['data_status', 'ano_status']].head()
# Out:
#     data_status ano_status
# 45   28/07/2022       2022
# 135  21/05/2020       2020
# 296  31/03/2025       2025
# 298  23/11/2023       2023
# 631  30/10/2008       2008

# %%
# 4) Seu código aqui
freq_anos = df_rj['ano_status'].value_counts().sort_index()
freq_anos
# Out:
# ano_status
# 2002     2
# 2006     1
# 2007     5
# 2008    10
# 2009     4
# 2010     1
# 2011     4
# 2012     7
# 2013     6
# 2014     6
# 2015     2
# 2016     4
# 2018     1
# 2019     2
# 2020     3
# 2022     1
# 2023     4
# 2025     2
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_pvl(uf, tipo_interessado):
    url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
    params = {'uf': uf, 'tipo_interessado': tipo_interessado}
    r = requests.get(url, params=params)
    data_json = r.json()
    df = pd.DataFrame(data_json['items'])
    return df

# %%
# 2) Seu código aqui
df_mg_estado = consulta_pvl('MG', 'Estado')
arquivadas_mg = df_mg_estado[df_mg_estado['status'] == 'Arquivado por decurso de prazo']
qtd_arquivadas_mg = len(arquivadas_mg)
qtd_arquivadas_mg
# Out:
# 1

# %%
# 3) Seu código aqui
df_ba_municipio = consulta_pvl('BA', 'Município')
deferidas_ba = df_ba_municipio[df_ba_municipio['status'] == 'Deferido']
mais_deferidos = deferidas_ba['interessado'].value_counts().idxmax()
mais_deferidos
# Out:
# 'Luís Eduardo Magalhães'

# %%
# 4) Seu código aqui
df_ba_estado = consulta_pvl('BA', 'Estado')
df_ba_estado.to_csv('solicitacoes_bahia_estado.csv', index=False)
